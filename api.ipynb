# %%
from flask import *
import json, time

#create the api
app = Flask(__name__)

@app.route('/', methods = ['GET'])
def home_page():
    data_set = {'quote': 'I channel Will Ferrell when I am at the daddy daughter dances'}
    json_dump = json.dumps(data_set)
    return json_dump

if __name__ == '__main__':
    app.run(port = 7778)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:7778/ (Press CTRL+C to quit)
# 127.0.0.1 - - [17/Jan/2022 20:27:10] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Jan/2022 20:27:10] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [17/Jan/2022 20:27:47] "GET / HTTP/1.1" 200 -
